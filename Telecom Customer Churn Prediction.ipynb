# %% [markdown]
# # Telecom Customer Churn

# %% [markdown]
# Description

# %%
#Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib.inline
import plotly.plotly as py
import plotly.graph_objs as go
import seaborn as sns
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
#Importing Dataset

tchurn = pd.read_csv("Churn.csv")

# %%
#Grabbing the first five records in the dataset to have a look at the columns
tchurn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
# Dimensions of the entire dataset
#7043 rows
#21 columns 

tchurn.shape
# Out:
# (7043, 21)

# %%
tchurn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
print(tchurn.info())
tchurn.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
tchurn['TotalCharges'] = tchurn["TotalCharges"].replace(" ",np.nan)

# %%
tchurn = tchurn[tchurn["TotalCharges"].notnull()]
tchurn = tchurn.reset_index()[tchurn.columns]

tchurn["TotalCharges"] = tchurn["TotalCharges"].astype(float)

# %%
tchurn.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
tchurn["SeniorCitizen"] = tchurn["SeniorCitizen"].replace({1:"Yes",0:"No"})

# %%
col_to_replace = ['StreamingMovies','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport',
                  'StreamingTV']
for i in col_to_replace:
    tchurn[i]=tchurn[i].replace({"No internet service":"No"})

# %%
tchurn["tenure"].max()
# Out:
# 72

# %%
def tenure_range(tchurn):
    if tchurn["tenure"] <= 12:
        return("0-1 Year")
    
    elif tchurn["tenure"] >12 and tchurn["tenure"] <=24:
        return("1-2 Year")
    
    elif tchurn["tenure"] >24 and tchurn["tenure"] <=36:
        return("2-3 Year")
    
    elif tchurn["tenure"] >36 and tchurn["tenure"] <=48:
        return("3-4 Year")
    
    elif tchurn["tenure"] > 48 and tchurn["tenure"] <=60:
        return("4-5 Year")
    
    elif tchurn["tenure"] >60 and tchurn["tenure"] <=72:
        return("5-6 Year")

# %%
tchurn["tenure"]=tchurn.apply(lambda tchurn:tenure_range(tchurn),axis=1)

# %%
tchurn
# Out:
#       customerID  gender SeniorCitizen Partner Dependents    tenure  \
# 0     7590-VHVEG  Female            No     Yes         No  0-1 Year
# 1     5575-GNVDE    Male            No      No         No  2-3 Year
# 2     3668-QPYBK    Male            No      No         No  0-1 Year
# 3     7795-CFOCW    Male            No      No         No  3-4 Year
# 4     9237-HQITU  Female            No      No         No  0-1 Year
# 5     9305-CDSKC  Female            No      No         No  0-1 Year
# 6     1452-KIOVK    Male            No      No        Yes  1-2 Year
# 7     6713-OKOMC  Female            No      No         No  0-1 Year
# 8     7892-POOKP  Female            No     Yes         No  2-3 Year
# 9     6388-TABGU    Male            No      No        Yes  5-6 Year
# 10    9763-GRSKD    Male            No     Yes        Yes  1-2 Year
# 11    7469-LKBCI    Male            No      No         No  1-2 Year
# 12    8091-TTVAX    Male            No     Yes         No  4-5 Year
# ...

# %%
churn_yes = tchurn[tchurn["Churn"]=="Yes"]
churn_no = tchurn[tchurn["Churn"]=="No"]

# %%
import seaborn as sns

sns.distplot(tchurn['MonthlyCharges'],kde=False)
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tchurn['TotalCharges'],kde=False)
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(tchurn['MonthlyCharges'])
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(tchurn['TotalCharges'])
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='MonthlyCharges',y='TotalCharges',data=tchurn)
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tchurn,hue='Churn')
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tchurn,hue='tenure')
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x='gender',data=tchurn)

# %%
sns.countplot(x='tenure',data=tchurn,hue='Churn')

# %%
sns.barplot(x='gender',y='TotalCharges',data=tchurn)
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
t = tchurn.corr()
sns.heatmap(t)

# %%
sns.barplot(x='tenure',y='TotalCharges',data=tchurn,hue='Churn')
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='tenure',y='MonthlyCharges',data=tchurn,hue='Churn')
# Out:
# C:\Users\js2536\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
correlation = tchurn.corr()
matrix_cols = correlation.columns.tolist()

# %%
corr_array  = np.array(correlation)

# %%
corr_array
# Out:
# array([[1.       , 0.6510648],
#        [0.6510648, 1.       ]])
